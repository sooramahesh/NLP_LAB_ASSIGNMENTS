# %% [markdown]
# <a href="https://colab.research.google.com/github/sooramahesh/NLP_LAB_ASSIGNMENTS/blob/main/NLP10_09LAB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import pandas as pd
from matplotlib import pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls /content/drive/MyDrive
# Out:
# '10th results'				  'movie .pdf'
#  Aadhaar.pdf				  'OBC Certificate.jpg'
# 'BharathIntern Payment (1).jpg'		  'Passport size Photo'
# 'BharathIntern Payment.jpg'		  'police admit.pdf'
#  Bharatintern				   pooja-receipt_1606698658008.pdf
#  BPL					  'Receipt_1_30_2022 12_00_00 AM (1).pdf'
# 'Colab Notebooks'			  'Receipt_1_30_2022 12_00_00 AM.pdf'
#  ConfirmationPage-220320149431.pdf	  'Receipt_9_15_2022 12_00_00 AM.pdf'
#  Events.pdf				   Results
#  Family					  'School Challen'
# 'Fee Receipt_10_27_2021 12_00_00 AM.pdf'  'Secondary School Examination (Class X) 2020.pdf'
# 'Getting started.pdf'			   Signature
# 'Hallticket (3).pdf'			  'Soora Mahesh Bharath intern.pdf'
#  insurance_data.csv			  'Soora Mahesh.pdf'
# 'Mahesh PAN CARD.pdf'			  'srija feefaid.pdf'
# 'Mahesh Results.gdoc'			   TSLPRB22_P2.pdf
# 'Mahesh Results.pdf'			   uppalaiah.pdf

# %%
file_path = '/content/drive/MyDrive/insurance_data.csv'
df = pd.read_csv(file_path)

# %%
df.head(10)
# Out:
#    age  affordibility  bought_insurance
# 0   22              1                 0
# 1   25              0                 0
# 2   47              1                 1
# 3   52              0                 0
# 4   46              1                 1
# 5   56              1                 1
# 6   55              0                 0
# 7   60              0                 1
# 8   62              1                 1
# 9   61              1                 1
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['age'].plot(kind='hist', bins=20, title='age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['affordibility'].plot(kind='hist', bins=20, title='affordibility')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['bought_insurance'].plot(kind='hist', bins=20, title='bought_insurance')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_3.plot(kind='scatter', x='age', y='affordibility', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='affordibility', y='bought_insurance', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_5['age'].plot(kind='line', figsize=(8, 4), title='age')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6['affordibility'].plot(kind='line', figsize=(8, 4), title='affordibility')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7['bought_insurance'].plot(kind='line', figsize=(8, 4), title='bought_insurance')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df[['age','affordibility']],
                                                    df.bought_insurance,test_size=0.2, random_state=25)

# %%
X_train_scaled = X_train.copy()
X_train_scaled['age'] = X_train_scaled['age'] / 100

X_test_scaled = X_test.copy()
X_test_scaled['age'] = X_test_scaled['age']/100

# %%
model = keras.Sequential([
    keras.layers.Dense(1, input_shape=(2,), activation='sigmoid', kernel_initializer='ones', bias_initializer='zeros')
])

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# Train the model and capture the history
history = model.fit(X_train_scaled, y_train, epochs=5000, verbose=0)

# Plot the training loss and accuracy curves
plt.figure(figsize=(12, 5))

# Plot training loss
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.title('Loss Curve')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot training accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.title('Accuracy Curve')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.evaluate(X_test_scaled,y_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 1.0000 - loss: 0.3550
# [0.3549776077270508, 1.0]

# %%
X_test_scaled
# Out:
#      age  affordibility
# 2   0.47              1
# 10  0.18              1
# 21  0.26              0
# 11  0.28              1
# 14  0.49              1
# 9   0.61              1

# %%
model.predict(X_test_scaled)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 829ms/step
# array([[0.7054848 ],
#        [0.3556957 ],
#        [0.16827832],
#        [0.47801185],
#        [0.7260696 ],
#        [0.8294983 ]], dtype=float32)

# %%
coef, intercept = model.get_weights()

# %%
coef, intercept
# Out:
# (array([[5.060863 ],
#         [1.4086521]], dtype=float32),
#  array([-2.913703], dtype=float32))
